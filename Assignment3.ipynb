# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
# Load the train and test datasets
train_dataset = pd.read_csv('Google_Stock_Price_Train.csv')
test_dataset = pd.read_csv('Google_Stock_Price_Test.csv')

# %%
# Inspect the dataset
print("Dataset Preview:")
print(train_dataset.head())

print(train_dataset.dtypes)

print("\nDataset Info:")
print(train_dataset.info())

# Check for missing values
print("\nMissing Values:")
print(train_dataset.isnull().sum())
# Out:
# Dataset Preview:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close      object
# Volume     object
# dtype: object
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB
# None
#
# Missing Values:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Define numerical columns for preprocess
num_columns = ['Open', 'High', 'Low', 'Close', 'Volume']


# Clean and convert columns (i.e., they contain strings)
# if columns contain string values i.e. commas in number cleaning them to numeric

for col in num_columns:
    if train_dataset[col].dtype == 'object':  # Check if column is string
        train_dataset[col] = train_dataset[col].str.replace(',', '').astype(float)
    if test_dataset[col].dtype == 'object':  # Check if column is string
        test_dataset[col] = test_dataset[col].str.replace(',', '').astype(float)

# %%
#Visualize the 'Open' prices in the training dataset over time
plt.figure(figsize=(12, 6))
plt.plot(train_dataset['Open'], label='Open Price', color='blue')
plt.title("Google Stock Opening Prices Over Time")
plt.xlabel("Time Steps")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
# Normalize features by using MinMaxScaler
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_dataset[num_columns])
test_scaled = scaler.transform(test_dataset[num_columns])

# %%
# Define sequence creation function
def create_sequences(data, sequence_length, target_index):
    X, y = [], []
    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i])  # Use the past `sequence_length` rows as input
        y.append(data[i, target_index])  # Target is the value at `target_index`
    return np.array(X), np.array(y)

# %%
# Set sequence length and target index
sequence_length = 30
target_index = 3  # for 'Close' price

# Create sequences for training
X_train_full, y_train_full = create_sequences(train_scaled, sequence_length, target_index)

# Spliting training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# prepare test data by Combine last `sequence_length` rows of training data with test data for testing
combined_data = np.vstack((train_scaled[-sequence_length:], test_scaled))
X_test, y_test = create_sequences(combined_data, sequence_length, target_index)


print(f"X_train shape: {X_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (982, 30, 5)
# X_val shape: (246, 30, 5)
# X_test shape: (20, 30, 5)
# y_train shape: (982,)
# y_val shape: (246,)
# y_test shape: (20,)

# %%
# Define LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
lstm_model.add(Dropout(0.3)) #for overfitting
lstm_model.add(LSTM(128, return_sequences=False))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')#Mean Squared Error loss

# Training LSTM model
lstm_history = lstm_model.fit(X_train, y_train,validation_data=(X_val, y_val),epochs=50,batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - loss: 0.0479 - val_loss: 0.0105
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0063 - val_loss: 0.0051
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0025 - val_loss: 8.6861e-04
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 0.0027 - val_loss: 7.8664e-04
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 0.0019 - val_loss: 7.7028e-04
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0024 - val_loss: 7.4491e-04
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0036 - val_loss: 9.1084e-04
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 0.0016 - val_loss: 7.9645e-04
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0027 - val_loss: 5.9954e-04
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 0.0024 - val_loss: 6.2970e-04
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0021 - val_loss: 7.0972e-04
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0042 - val_loss: 6.6402e-04
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0028 - val_loss: 6.6279e-04
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0020 - val_loss: 4.9810e-04
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 0.0015 - val_loss: 8.6159e-04
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 0.0034 - val_loss: 6.3721e-04
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0020 - val_loss: 4.5833e-04
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0019 - val_loss: 7.7586e-04
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - loss: 0.0034 - val_loss: 4.5394e-04
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0010 - val_loss: 7.6904e-04
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0013 - val_loss: 5.4764e-04
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0026 - val_loss: 4.7844e-04
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0016 - val_loss: 4.5387e-04

# %%
# Evaluate LSTM model
lstm_loss = lstm_model.evaluate(X_test, y_test, verbose=1)
lstm_pred = lstm_model.predict(X_test).flatten()

# Compute LSTM metrics
lstm_rmse = np.sqrt(mean_squared_error(y_test, lstm_pred))
lstm_mae = mean_absolute_error(y_test, lstm_pred)
print(f"LSTM Loss: {lstm_loss}, RMSE: {lstm_rmse}, MAE: {lstm_mae}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.0376e-04
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b4a80185bd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# LSTM Loss: 0.00030376267386600375, RMSE: 0.01742878926725751, MAE: 0.013773515120099566

# %%
# Define GRU model
gru_model = Sequential()
gru_model.add(GRU(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
gru_model.add(Dropout(0.3))
gru_model.add(GRU(128, return_sequences=False))
gru_model.add(Dropout(0.3))
gru_model.add(Dense(1))
gru_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train GRU model
gru_history = gru_model.fit(X_train, y_train,validation_data=(X_val, y_val),epochs=50,batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - loss: 0.0310 - val_loss: 0.0030
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0067 - val_loss: 0.0014
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0054 - val_loss: 9.3867e-04
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0031 - val_loss: 6.6377e-04
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0023 - val_loss: 7.7244e-04
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0023 - val_loss: 5.2949e-04
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0052 - val_loss: 4.7480e-04
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0023 - val_loss: 5.3534e-04
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0029 - val_loss: 5.9899e-04
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 0.0025 - val_loss: 6.2282e-04
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0019 - val_loss: 9.6009e-04
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0020 - val_loss: 9.7593e-04
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0021 - val_loss: 5.8828e-04
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0025 - val_loss: 4.2367e-04
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0015 - val_loss: 5.2845e-04
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0019 - val_loss: 4.7641e-04
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0015 - val_loss: 3.5712e-04
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0023 - val_loss: 5.8614e-04
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0037 - val_loss: 5.5832e-04
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0022 - val_loss: 3.6679e-04
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0015 - val_loss: 7.5953e-04
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0015 - val_loss: 6.8186e-04
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 0.0025 - val_loss: 4.3277e-04
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0024 - val_loss: 4.1523e-04
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0015 - val_loss: 6.0973e-04
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0014 - val_loss: 5.7024e-04
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0017 - val_loss: 3.4902e-04
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0017 - val_loss: 9.2105e-04
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0020 - val_loss: 3.1675e-04
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0012 - val_loss: 2.7712e-04
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0016 - val_loss: 3.5446e-04
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0017 - val_loss: 3.1730e-04
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0020 - val_loss: 5.4752e-04
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0018 - val_loss: 3.3452e-04
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0033 - val_loss: 2.9182e-04
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0013 - val_loss: 5.4191e-04
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0013 - val_loss: 4.5964e-04
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0016 - val_loss: 3.3772e-04
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0010 - val_loss: 4.0152e-04
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0019 - val_loss: 6.2648e-04
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0017 - val_loss: 5.3103e-04
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0014 - val_loss: 7.6449e-04
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0018 - val_loss: 3.4942e-04
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0014 - val_loss: 3.2826e-04
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0016 - val_loss: 4.0624e-04
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0012 - val_loss: 0.0011

# %%
# Evaluate GRU model
gru_loss = gru_model.evaluate(X_test, y_test, verbose=1)
gru_pred = gru_model.predict(X_test).flatten()

# Compute GRU metrics
gru_rmse = np.sqrt(mean_squared_error(y_test, gru_pred))
gru_mae = mean_absolute_error(y_test, gru_pred)
print(f"GRU Loss: {gru_loss}, RMSE: {gru_rmse}, MAE: {gru_mae}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0013
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b4a890f7400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# GRU Loss: 0.0012697626370936632, RMSE: 0.03563373152392029, MAE: 0.034099022151575696

# %%
# Compute metrics
lstm_rmse = np.sqrt(mean_squared_error(y_test, lstm_pred))
lstm_mae = mean_absolute_error(y_test, lstm_pred)
gru_rmse = np.sqrt(mean_squared_error(y_test, gru_pred))
gru_mae = mean_absolute_error(y_test, gru_pred)


# Print results
print(f"LSTM Loss: {lstm_loss}, RMSE: {lstm_rmse}, MAE: {lstm_mae}")
print(f"GRU Loss: {gru_loss}, RMSE: {gru_rmse}, MAE: {gru_mae}")
# Out:
# LSTM Loss: 0.00030376267386600375, RMSE: 0.01742878926725751, MAE: 0.013773515120099566
# GRU Loss: 0.0012697626370936632, RMSE: 0.03563373152392029, MAE: 0.034099022151575696

# %%
# Define metrics
data = {
    'Model': ['LSTM', 'GRU'],
    'Test Loss (MSE)': [lstm_loss, gru_loss],  # Replace with actual loss values
    'RMSE': [lstm_rmse, gru_rmse],
    'MAE': [lstm_mae, gru_mae]
}

# Create a DataFrame
comparison_table = pd.DataFrame(data)

# Display the table
print("\nComparison Table:")
print(comparison_table)
# Out:
# Comparison Table:
#   Model  Test Loss (MSE)      RMSE       MAE
# 0  LSTM         0.000304  0.017429  0.013774
# 1   GRU         0.001270  0.035634  0.034099

# %%
# Visualize training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(lstm_history.history['loss'], label='LSTM Training Loss')
plt.plot(lstm_history.history['val_loss'], label='LSTM Validation Loss')
plt.plot(gru_history.history['loss'], label='GRU Training Loss')
plt.plot(gru_history.history['val_loss'], label='GRU Validation Loss')
plt.title('Training vs Validation Loss (LSTM vs GRU)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Visualize actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual Values', alpha=0.7)
plt.plot(lstm_pred, label='LSTM Predictions', alpha=0.7)
plt.plot(gru_pred, label='GRU Predictions', alpha=0.7)
plt.title('Actual vs Predicted Values (LSTM vs GRU)')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# residuals for LSTM
lstm_residuals = y_test - lstm_pred

# residuals for GRU
gru_residuals = y_test - gru_pred

plt.figure(figsize=(12, 6))
plt.scatter(range(len(lstm_residuals)), lstm_residuals, label='LSTM Residuals', alpha=0.7, color='red')
plt.scatter(range(len(gru_residuals)), gru_residuals, label='GRU Residuals', alpha=0.7, color='green')
plt.axhline(0, color='black', linestyle='--')
plt.title("Residual Plot (LSTM vs GRU)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.legend()
plt.show()
